# %%
import pandas as pd 
import datetime as dt
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df_tr = pd.read_excel (r'Updated_dataset.xlsx', sheet_name='Transactions')
df_nc = pd.read_excel (r'Updated_dataset.xlsx', sheet_name='NewCustomerList')
df_cd = pd.read_excel (r'Updated_dataset.xlsx', sheet_name='CustomerDemographic')
df_ca = pd.read_excel (r'Updated_dataset.xlsx', sheet_name='CustomerAddress')

# %%
df_nc.head()
# Out:
#    Unnamed: 0 first_name  last_name  gender  \
# 0           0    Chickie    Brister    Male
# 1           1      Morly     Genery    Male
# 2           2    Ardelis  Forrester  Female
# 3           3     Lucine      Stutt  Female
# 4           4    Melinda     Hadlee  Female
#
#    past_3_years_bike_related_purchases        DOB   Age  \
# 0                                   86 1957-07-12  63.0
# 1                                   69 1970-03-22  50.0
# 2                                   10 1974-08-28  46.0
# 3                                   64 1979-01-28  41.0
# 4                                   34 1965-09-21  55.0
#
#                     job_title job_industry_category     wealth_segment  ...  \
# 0             General Manager         Manufacturing      Mass Customer  ...
# 1         Structural Engineer              Property      Mass Customer  ...
# 2      Senior Cost Accountant    Financial Services  Affluent Customer  ...
# ...

# %%
dups = df_nc.pivot_table(index = ['AgeGroup'], aggfunc ='size')
print(dups)
# Out:
# AgeGroup
# 10-20     13
# 20-30    169
# 30-40    102
# 40-50    229
# 50-60    175
# 60-70    170
# 70-80     91
# 80+       34
# dtype: int64

# %%
df_dup = pd.DataFrame(dups, columns = ['dups'])

# %%
df_dup
# Out:
#           dups
# AgeGroup
# 10-20       13
# 20-30      169
# 30-40      102
# 40-50      229
# 50-60      175
# 60-70      170
# 70-80       91
# 80+         34

# %%
sns.barplot(y=dups,x =dups.index,data=df_dup).set_title('New Customers Age Ditribution')
plt.show()

# %%
df_cd.head()
# Out:
#    Unnamed: 0  customer_id      first_name  last_name  gender  \
# 0           0            1         Laraine  Medendorp  Female
# 1           1            2             Eli    Bockman    Male
# 2           2            3           Arlin     Dearle    Male
# 3           3            4          Talbot        NaN    Male
# 4           4            5  Sheila-kathryn     Calton  Female
#
#    past_3_years_bike_related_purchases        DOB   Age  \
# 0                                   93 1953-10-12  67.0
# 1                                   81 1980-12-16  39.0
# 2                                   61 1954-01-20  66.0
# 3                                   33 1961-10-03  59.0
# 4                                   56 1977-05-13  43.0
#
#                 job_title job_industry_category     wealth_segment  \
# 0     Executive Secretary                Health      Mass Customer
# 1  Administrative Officer    Financial Services      Mass Customer
# ...

# %%
dups_cd = df_cd.pivot_table(index = ['AgeGroup'], aggfunc ='size')
print(dups_cd)
# Out:
# AgeGroup
# 10-20      43
# 20-30     675
# 30-40     687
# 40-50    1338
# 50-60     697
# 60-70     467
# 70-80       2
# 80+         3
# dtype: int64

# %%
dfcd_dup = pd.DataFrame(dups_cd, columns = ['dups'])
dfcd_dup
# Out:
#           dups
# AgeGroup
# 10-20       43
# 20-30      675
# 30-40      687
# 40-50     1338
# 50-60      697
# 60-70      467
# 70-80        2
# 80+          3

# %%
sns.barplot(y=dups_cd,x =dups_cd.index,data=dfcd_dup).set_title('Old Customers Age Ditribution')
plt.show()

# %%
df_cd.head()
# Out:
#    Unnamed: 0  customer_id      first_name  last_name  gender  \
# 0           0            1         Laraine  Medendorp  Female
# 1           1            2             Eli    Bockman    Male
# 2           2            3           Arlin     Dearle    Male
# 3           3            4          Talbot        NaN    Male
# 4           4            5  Sheila-kathryn     Calton  Female
#
#    past_3_years_bike_related_purchases        DOB   Age  \
# 0                                   93 1953-10-12  67.0
# 1                                   81 1980-12-16  39.0
# 2                                   61 1954-01-20  66.0
# 3                                   33 1961-10-03  59.0
# 4                                   56 1977-05-13  43.0
#
#                 job_title job_industry_category     wealth_segment  \
# 0     Executive Secretary                Health      Mass Customer
# 1  Administrative Officer    Financial Services      Mass Customer
# ...

# %%
sns.barplot(x=df_cd.gender,y =df_cd.past_3_years_bike_related_purchases,data=df_cd,ci=None).set(xlabel='Gender', ylabel='No. of purchases',title='Bike related purchases in last 3 years')
plt.show()
