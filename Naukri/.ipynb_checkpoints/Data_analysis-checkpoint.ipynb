# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
df = pd.read_csv('Naukri_cleaned.csv')

# %%
df.head(1)
# Out:
#    Unnamed: 0             Job Title            Job Salary  \
# 0           0   Document Specialist  1,00,000-1,25,000pa.
#
#   Job Experience Required                                      Key Skills  \
# 0               0 - 1 yrs   Word Excel Powerpoint MS Office Suite Fresher
#
#   Role Category Location                                    Functional Area  \
# 0         Other  Chennai  ITES , BPO , KPO , LPO , Customer Service , Op...
#
#                  Industry     Role  min_salary  max_salary  avg_salary  \
# 0  BPO, Call Centre, ITeS  Fresher      100000      125000      112500
#
#    min_experience  max_experience
# 0               0               1

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'Job Title', 'Job Salary', 'Job Experience Required',
#        'Key Skills', 'Role Category', 'Location', 'Functional Area',
#        'Industry', 'Role', 'min_salary', 'max_salary', 'avg_salary',
#        'min_experience', 'max_experience'],
#       dtype='object')

# %%
df.Role.value_counts()
# Out:
# Software Developer                                                   847
# Associate/Senior Associate -(NonTechnical)                           613
# Other                                                                432
# Sales/Business Development Manager                                   423
# Sales Executive/Officer                                              362
# Fresher                                                              217
# Recruitment Executive                                                175
# Accounts Executive/Accountant                                        155
# Associate/Senior Associate -(Technical)                              126
# Telecalling/Telemarketing Executive                                  117
# HR Executive                                                         104
# Team Lead/Technical Lead                                              90
# Medical Officer                                                       68
# ...

# %%
fig = plt.figure(figsize = (10,5))
ax = fig.gca()
df.avg_salary.hist(ax =ax)

# %%
fig = plt.figure(figsize = (10,5))
ax = fig.gca()
df.min_experience.hist(ax =ax)

# %%
fig = plt.figure(figsize = (10,5))
ax = fig.gca()
df.max_experience.hist(ax =ax)

# %%
cmap = sns.diverging_palette(230, 20, as_cmap=True)
sns.heatmap(df[['Location', 'min_salary', 'max_salary']].corr(),cmap =cmap, vmax=.3, center=0,
            square=True, linewidths=.5, cbar_kws={"shrink": .5})

# %%
df_cat = df[['Location', 'avg_salary', 'max_experience', 'min_experience', 'Role Category', 'Role']]
for i in df_cat.columns:
    cat_num = df_cat[i].value_counts(sort=True).nlargest(25)
    print("Graph for %s: total %d"%(i, len(cat_num)))
    fig_dims = (16, 5)
    fig, ax = plt.subplots(figsize=fig_dims)
    chart = sns.barplot(x=cat_num.index, y=cat_num, ax =ax)
    chart.set_xticklabels(chart.get_xticklabels(), rotation =90)
    plt.show()
# Out:
# Graph for Location: total 25
# Graph for avg_salary: total 25
# Graph for max_experience: total 25
# Graph for min_experience: total 23
# Graph for Role Category: total 25
# Graph for Role: total 25

# %%
pd.options.display.max_rows
pd.set_option('display.max_rows', None)
pd.pivot_table(df, index='Role', values ='avg_salary', aggfunc = 'count').sort_values('Role')
# Out:
#                                                     avg_salary
# Role
# 4th Engineer                                                 1
# Academic Coordinator                                         1
# Accessory Designer                                           1
# Accounts Executive/Accountant                              155
# Accounts Manager                                            49
# Administration Services/Medical Facilities                   4
# Advisor/Outside Consultant                                   1
# Affiliate Marketing Manager                                  2
# Anaesthetist                                                 5
# Analyst                                                      4
# Analytical Chemistry Associate/Scientist                     1
# Analytics Manager                                            8
# Animation Designer                                           6
# Animation/Graphic Artist                                     2
# ...

# %%
from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator

# %%
text = " ".join(review for review in df['Key Skills'])
stopwords = set(STOPWORDS)
#text = df['Key Skills'][0]
wordcloud = WordCloud(width=1600, height=800, stopwords=stopwords, background_color="white").generate(text)
plt.figure(figsize=(10,5))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()
